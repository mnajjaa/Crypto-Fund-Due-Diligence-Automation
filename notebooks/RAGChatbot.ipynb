# %%
! pip install langchain langsmith huggingface_hub transformers sentence-transformers  unstructured tiktoken
! pip install pypdf python-docx
! pip install -U langchain-community
! pip install -q langchain ctransformers
! pip install langchain_chroma -q
# Out:
# Requirement already satisfied: langchain in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (0.3.24)
# Requirement already satisfied: langsmith in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (0.3.33)
# Requirement already satisfied: huggingface_hub in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (0.30.2)
# Requirement already satisfied: transformers in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (4.51.3)
# Requirement already satisfied: sentence-transformers in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (4.1.0)
# Requirement already satisfied: unstructured in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (0.17.2)
# Requirement already satisfied: tiktoken in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (0.9.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.55 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain) (0.3.55)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain) (2.11.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langsmith) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langsmith) (3.10.16)
# Requirement already satisfied: packaging>=23.2 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langsmith) (24.2)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langsmith) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langsmith) (0.23.0)
# Requirement already satisfied: filelock in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from huggingface_hub) (2025.3.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from transformers) (2.2.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: torch>=1.11.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: scikit-learn in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from sentence-transformers) (1.15.2)
# Requirement already satisfied: Pillow in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: chardet in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured) (5.3.2)
# Requirement already satisfied: nltk in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured) (4.13.3)
# Requirement already satisfied: emoji in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured) (2.14.1)
# Requirement already satisfied: dataclasses-json in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured) (2025.2.18)
# Requirement already satisfied: langdetect in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: rapidfuzz in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured) (3.13.0)
# Requirement already satisfied: backoff in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: unstructured-client in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured) (0.33.1)
# Requirement already satisfied: wrapt in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured) (1.17.2)
# Requirement already satisfied: psutil in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured) (7.0.0)
# Requirement already satisfied: python-oxmsg in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: html5lib in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured) (1.1)
# Requirement already satisfied: anyio in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith) (4.9.0)
# Requirement already satisfied: certifi in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith) (1.0.8)
# Requirement already satisfied: idna in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith) (0.14.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (1.33)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: greenlet>=1 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.0)
# Requirement already satisfied: networkx in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.5)
# Requirement already satisfied: setuptools in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.8.2)
# Requirement already satisfied: sympy==1.13.1 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from beautifulsoup4->unstructured) (2.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from dataclasses-json->unstructured) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six>=1.9 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from html5lib->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from nltk->unstructured) (8.1.8)
# Requirement already satisfied: joblib in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: olefile in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured-client->unstructured) (24.1.0)
# Requirement already satisfied: cryptography>=3.1 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured-client->unstructured) (44.0.2)
# Requirement already satisfied: eval-type-backport>=0.2.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured-client->unstructured) (0.2.2)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: pypdf>=4.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured-client->unstructured) (5.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from unstructured-client->unstructured) (2.9.0.post0)
# Requirement already satisfied: cffi>=1.12 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.55->langchain) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: pycparser in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.22)
# Requirement already satisfied: pypdf in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (5.4.0)
# Requirement already satisfied: python-docx in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (1.1.2)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from python-docx) (5.3.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from python-docx) (4.12.2)
# Requirement already satisfied: langchain-community in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (0.3.22)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.55 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-community) (0.3.55)
# Requirement already satisfied: langchain<1.0.0,>=0.3.24 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-community) (0.3.24)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-community) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-community) (3.11.18)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-community) (0.3.33)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-community) (2.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain<1.0.0,>=0.3.24->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain<1.0.0,>=0.3.24->langchain-community) (2.11.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from requests<3,>=2->langchain-community) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.0)
# Requirement already satisfied: anyio in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.55->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.24->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.24->langchain-community) (2.33.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)

# %%
# LangChain core
from langchain.chains import RetrievalQA
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.llms import HuggingFaceHub
from langchain.document_loaders import UnstructuredFileLoader, PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from typing import List
from langchain_core.documents import Document
import os

def load_docs(folder_path: str) -> List[Document]:
    documents = []
    for file in os.listdir(folder_path):
        if file.endswith(".pdf"):
            pdf_path = os.path.join(folder_path, file)
        else:
            print(f"Unsupported file format: {file}")
            continue
        loader = PyPDFLoader(file_path=pdf_path)
        documents.extend(loader.load())
    return documents

folder_path = "docs"
documents = load_docs(folder_path)

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=100,
    length_function=len,
)


splits = text_splitter.split_documents(documents)
print(f"Split the docs into {len(splits)} chunks")
# Out:
# Split the docs into 110 chunks

# %%
splits[0]
# Out:
# Document(metadata={'producer': 'OpenOffice.org 2.4', 'creator': 'Writer', 'creationdate': '2009-03-24T11:33:15-06:00', 'source': 'docs\\bitcoin_whitepaper.pdf', 'total_pages': 9, 'page': 0, 'page_label': '1'}, page_content='Bitcoin: A Peer-to-Peer Electronic Cash System\nSatoshi Nakamoto\nsatoshin@gmx.com\nwww.bitcoin.org\nAbstract.  A purely peer-to-peer version of  electronic cash would allow online  \npayments to be sent directly from one party to another without going through a')

# %%
from langchain_community.embeddings.sentence_transformer import SentenceTransformerEmbeddings

embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
doc_embeds = embeddings.embed_documents([split.page_content for split in splits])
doc_embeds[0]
# Out:
# [-0.0911194309592247,
#  0.03640065714716911,
#  -0.006011271849274635,
#  -0.03416364639997482,
#  -0.062013838440179825,
#  -0.0771283432841301,
#  0.09881779551506042,
#  -0.005686826538294554,
#  -0.020200684666633606,
#  0.027311014011502266,
#  -0.010944324545562267,
#  0.007337226066738367,
#  -0.005205228459089994,
#  -0.017424169927835464,
#  0.05288303643465042,
#  -0.008167163468897343,
#  0.00898760836571455,
#  -0.010909239761531353,
#  0.09112106263637543,
#  0.05003901571035385,
#  0.06945016980171204,
#  -0.010098570957779884,
#  -0.04415997490286827,
#  0.043444205075502396,
#  0.09239205718040466,
#  0.0729353204369545,
#  0.055053140968084335,
#  0.0013761186273768544,
#  0.016158023849129677,
#  0.04124752804636955]

# %%
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import SentenceTransformerEmbeddings


embedding_function = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")


persist_directory = "db_rag"

# Create vector store
vectorstore = Chroma.from_documents(
    documents=splits,
    embedding=embedding_function,
    persist_directory=persist_directory,
    collection_name="rag-chatbot"
)

# %%
#smiliarity search

query = "What is the main objective of this project?"
search_results = vectorstore.similarity_search(query=query, k=2)
print(f"\nTop 2 most relevant chunks for the query '{query}':\n")
for i, result in enumerate(search_results, 1):
    print(f"Result {i}:")
    print(f"Source: {result.metadata.get('source', 'Unknown')}")
    print(f"Content: {result.page_content}")
    print()
# Out:
# Top 2 most relevant chunks for the query 'What is the main objective of this project?':
#
# Result 1:
# Source: docs\bitcoin (1).pdf
# Content: making.  If the majority were based on one-IP-address-one-vote, it could be subverted by anyone
# able  to  allocate  many  IPs.   Proof-of-work  is  essentially  one-CPU-one-vote.   The  majority
# decision is represented by the longest chain, which has the greatest proof-of-work effort invested
#
# Result 2:
# Source: docs\bitcoin_whitepaper.pdf
# Content: making.  If the majority were based on one-IP-address-one-vote, it could be subverted by anyone
# able  to  allocate  many  IPs.   Proof-of-work  is  essentially  one-CPU-one-vote.   The  majority
# decision is represented by the longest chain, which has the greatest proof-of-work effort invested

# %%
retriever = vectorstore.as_retriever(search_kwargs={"k": 4})
retriever.invoke("Who wrote the Bitcoin whitepaper?")
# Out:
# [Document(metadata={'creationdate': '2009-03-24T11:33:15-06:00', 'creator': 'Writer', 'page': 7, 'page_label': '8', 'producer': 'OpenOffice.org 2.4', 'source': 'docs\\bitcoin_whitepaper.pdf', 'total_pages': 9}, page_content='the usual framework of coins made from digital signatures, which provides strong control of  \nownership, but is incomplete without a way to prevent double-spending.  To solve this, we  \nproposed a peer-to-peer network using proof-of-work to record a public history of transactions'),
#  Document(metadata={'creationdate': '2009-03-24T11:33:15-06:00', 'creator': 'Writer', 'page': 7, 'page_label': '8', 'producer': 'OpenOffice.org 2.4', 'source': 'docs\\bitcoin (1).pdf', 'total_pages': 9}, page_content='the usual framework of coins made from digital signatures, which provides strong control of  \nownership, but is incomplete without a way to prevent double-spending.  To solve this, we  \nproposed a peer-to-peer network using proof-of-work to record a public history of transactions'),
#  Document(metadata={'creationdate': '2009-03-24T11:33:15-06:00', 'creator': 'Writer', 'page': 7, 'page_label': '8', 'producer': 'OpenOffice.org 2.4', 'source': 'docs\\bitcoin (1).pdf', 'total_pages': 9}, page_content='the usual framework of coins made from digital signatures, which provides strong control of  \nownership, but is incomplete without a way to prevent double-spending.  To solve this, we  \nproposed a peer-to-peer network using proof-of-work to record a public history of transactions'),
#  Document(metadata={'creationdate': '2009-03-24T11:33:15-06:00', 'creator': 'Writer', 'page': 7, 'page_label': '8', 'producer': 'OpenOffice.org 2.4', 'source': 'docs\\bitcoin (1).pdf', 'total_pages': 9}, page_content='the usual framework of coins made from digital signatures, which provides strong control of  \nownership, but is incomplete without a way to prevent double-spending.  To solve this, we  \nproposed a peer-to-peer network using proof-of-work to record a public history of transactions')]

# %%
from langchain_core.prompts import ChatPromptTemplate
template = """Answer the question based only on the following context:
{context}

Question: {question}

Answer: """
prompt = ChatPromptTemplate.from_template(template)

# %%
from langchain.schema.runnable import RunnablePassthrough
rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt

)
rag_chain.invoke("When was the Bitcoin whitepaper published?")
# Out:
# ChatPromptValue(messages=[HumanMessage(content="Answer the question based only on the following context:\n[Document(metadata={'creationdate': '2009-03-24T11:33:15-06:00', 'creator': 'Writer', 'page': 7, 'page_label': '8', 'producer': 'OpenOffice.org 2.4', 'source': 'docs\\\\bitcoin (1).pdf', 'total_pages': 9}, page_content='the usual framework of coins made from digital signatures, which provides strong control of  \\nownership, but is incomplete without a way to prevent double-spending.  To solve this, we  \\nproposed a peer-to-peer network using proof-of-work to record a public history of transactions'), Document(metadata={'creationdate': '2009-03-24T11:33:15-06:00', 'creator': 'Writer', 'page': 7, 'page_label': '8', 'producer': 'OpenOffice.org 2.4', 'source': 'docs\\\\bitcoin (1).pdf', 'total_pages': 9}, page_content='the usual framework of coins made from digital signatures, which provides strong control of  \\nownership, but is incomplete without a way to prevent double-spending.  To solve this, we  \\nproposed a peer-to-peer network using proof-of-work to record a public history of transactions'), Document(metadata={'creationdate': '2009-03-24T11:33:15-06:00', 'creator': 'Writer', 'page': 7, 'page_label': '8', 'producer': 'OpenOffice.org 2.4', 'source': 'docs\\\\bitcoin (1).pdf', 'total_pages': 9}, page_content='the usual framework of coins made from digital signatures, which provides strong control of  \\nownership, but is incomplete without a way to prevent double-spending.  To solve this, we  \\nproposed a peer-to-peer network using proof-of-work to record a public history of transactions'), Document(metadata={'creationdate': '2009-03-24T11:33:15-06:00', 'creator': 'Writer', 'page': 7, 'page_label': '8', 'producer': 'OpenOffice.org 2.4', 'source': 'docs\\\\bitcoin (1).pdf', 'total_pages': 9}, page_content='the usual framework of coins made from digital signatures, which provides strong control of  \\nownership, but is incomplete without a way to prevent double-spending.  To solve this, we  \\nproposed a peer-to-peer network using proof-of-work to record a public history of transactions')]\n\nQuestion: When was the Bitcoin whitepaper published?\n\nAnswer: ", additional_kwargs={}, response_metadata={})])

# %%
! pip install -U langchain-ollama
# Out:
# Requirement already satisfied: langchain-ollama in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (0.3.2)
# Requirement already satisfied: ollama<1,>=0.4.4 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-ollama) (0.4.8)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.52 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-ollama) (0.3.55)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-ollama) (0.3.33)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-ollama) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-ollama) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-ollama) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-ollama) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-ollama) (4.12.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.52->langchain-ollama) (2.11.3)
# Requirement already satisfied: httpx<0.29,>=0.27 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from ollama<1,>=0.4.4->langchain-ollama) (0.28.1)
# Requirement already satisfied: anyio in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (4.9.0)
# Requirement already satisfied: certifi in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (1.0.8)
# Requirement already satisfied: idna in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (3.10.16)
# Requirement already satisfied: requests<3,>=2 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.52->langchain-ollama) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\onedrive\documents\github\crypto-fund-due-diligence-automation\venv\lib\site-packages (from anyio->httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (1.3.1)

# %%
from langchain_ollama import OllamaLLM

llm_local = OllamaLLM(
    model="llama3",
    base_url="http://localhost:11434"
)

# %%
print(llm_local.invoke("Who created Bitcoin?"))
# Out:
# The creator of Bitcoin is a person or group of people known by the pseudonym Satoshi Nakamoto. Satoshi's true identity remains unknown, and it is not clear whether Satoshi is a single individual or a group of people working together.
#
# Satoshi published the Bitcoin whitepaper in October 2008, which outlined the basic design and concepts for the Bitcoin protocol. The first block in the Bitcoin blockchain, known as the Genesis Block, was mined by Satoshi on January 3, 2009.
#
# Throughout 2009 and early 2010, Satoshi was active in the online community surrounding Bitcoin, participating in discussions and helping to develop the network. However, in December 2010, Satoshi stopped contributing to the project and disappeared from public view.
#
# Since then, many people have attempted to uncover Satoshi's true identity, but none have been successful. Despite this, Satoshi's contribution to the development of Bitcoin has had a profound impact on the world of finance and technology.
#
# In 2019, Craig Wright, an Australian computer scientist and businessman, claimed to be Satoshi Nakamoto in a series of blog posts and interviews. However, many in the cryptocurrency community have questioned his claim, citing lack of concrete evidence and inconsistencies in his story. As a result, Satoshi's true identity remains a mystery.

# %%
rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    |llm_local
)
question = "What is Bitcoin?"
response = rag_chain.invoke(question)
print(response)
# Out:
# Bitcoin: A Peer-to-Peer Electronic Cash System

# %%
from langchain_core.messages import HumanMessage, AIMessage
chat_history = []
chat_history.extend([HumanMessage(content=question), AIMessage(content=response)])

# %%
chat_history
# Out:
# [HumanMessage(content='What is Bitcoin?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Bitcoin: A Peer-to-Peer Electronic Cash System', additional_kwargs={}, response_metadata={})]

# %%
from langchain_core.prompts import MessagesPlaceholder
contextualize_q_system_prompt = (
"Your ONLY task is to reformulate the user’s question so that it can stand alone without the chat history. Do NOT answer it"
)
contextualize_q_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", contextualize_q_system_prompt),
        MessagesPlaceholder("chat_history"),
        ("human", "{input}"),
    ]
)
contextualize_chain = contextualize_q_prompt | llm_local
contextualize_chain.invoke({"input": "How does it solve the problem of double spending?", "chat_history": chat_history})
# Out:
# 'How does Bitcoin, a peer-to-peer electronic cash system, prevent double spending of its digital currency units?'

# %%
from langchain.chains import create_history_aware_retriever
history_aware_retriever = create_history_aware_retriever(
    llm_local, retriever, contextualize_q_prompt
)
history_aware_retriever.invoke({"input":"How does it solve the problem of double spending?", "chat_history": chat_history})
# Out:
# [Document(metadata={'creationdate': '2009-03-24T11:33:15-06:00', 'creator': 'Writer', 'page': 0, 'page_label': '1', 'producer': 'OpenOffice.org 2.4', 'source': 'docs\\bitcoin (1).pdf', 'total_pages': 9}, page_content='Bitcoin: A Peer-to-Peer Electronic Cash System\nSatoshi Nakamoto\nsatoshin@gmx.com\nwww.bitcoin.org\nAbstract.  A purely peer-to-peer version of  electronic cash would allow online  \npayments to be sent directly from one party to another without going through a'),
#  Document(metadata={'creationdate': '2009-03-24T11:33:15-06:00', 'creator': 'Writer', 'page': 0, 'page_label': '1', 'producer': 'OpenOffice.org 2.4', 'source': 'docs\\bitcoin (1).pdf', 'total_pages': 9}, page_content='Bitcoin: A Peer-to-Peer Electronic Cash System\nSatoshi Nakamoto\nsatoshin@gmx.com\nwww.bitcoin.org\nAbstract.  A purely peer-to-peer version of  electronic cash would allow online  \npayments to be sent directly from one party to another without going through a'),
#  Document(metadata={'creationdate': '2009-03-24T11:33:15-06:00', 'creator': 'Writer', 'page': 0, 'page_label': '1', 'producer': 'OpenOffice.org 2.4', 'source': 'docs\\bitcoin (1).pdf', 'total_pages': 9}, page_content='Bitcoin: A Peer-to-Peer Electronic Cash System\nSatoshi Nakamoto\nsatoshin@gmx.com\nwww.bitcoin.org\nAbstract.  A purely peer-to-peer version of  electronic cash would allow online  \npayments to be sent directly from one party to another without going through a'),
#  Document(metadata={'creationdate': '2009-03-24T11:33:15-06:00', 'creator': 'Writer', 'page': 0, 'page_label': '1', 'producer': 'OpenOffice.org 2.4', 'source': 'docs\\bitcoin_whitepaper.pdf', 'total_pages': 9}, page_content='Bitcoin: A Peer-to-Peer Electronic Cash System\nSatoshi Nakamoto\nsatoshin@gmx.com\nwww.bitcoin.org\nAbstract.  A purely peer-to-peer version of  electronic cash would allow online  \npayments to be sent directly from one party to another without going through a')]

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain

qa_prompt = ChatPromptTemplate.from_messages([
    ("system",
 "You are an intelligent assistant specialized in analyzing cryptocurrency whitepapers."
 "You must answer only using the provided context. "
 "If multiple relevant parts exist, combine them concisely."
 "Think carefully, reason step by step if needed, and base your answer entirely on the evidence provided. "
 "If the answer is not clearly in the context, reply with: 'The information is not available in the document.' "
 "Avoid any external knowledge or assumptions, and never fabricate details."
 "If possible, reference the page number or section from which the information was derived."
 "Do not generate academic references or citations unless explicitly instructed. Only cite document sections if clearly provided in the context."
)
,

    ("system", "Context: {context}"),
    MessagesPlaceholder(variable_name="chat_history"),
    ("human", "{input}")
])

question_answer_chain = create_stuff_documents_chain(llm_local, qa_prompt)
rag_chain_final = create_retrieval_chain(history_aware_retriever, question_answer_chain)

# %%
response = rag_chain_final.invoke({
    "input": "How does Bitcoin prevent double spending without a central authority?",
    "chat_history": chat_history
})

print(response["answer"])
# Out:
# According to the document "Bitcoin: A Peer-to-Peer Electronic Cash System" by Satoshi Nakamoto, Bitcoin prevents double spending without a central authority through the use of a distributed ledger called the blockchain. The blockchain is maintained by a network of nodes that verify and validate transactions using cryptographic hash functions.
#
# On page 1, it states: "The main problem with electronic payments has been the need to rely on a third party to process these transactions." This implies that traditional payment systems require a central authority, which can be prone to errors or manipulation. In contrast, Bitcoin's decentralized nature eliminates the need for such an intermediary.
#
# To prevent double spending, the document explains that each transaction is combined into a block and then linked to the previous block through a unique digital fingerprint called a "hash." This creates a chain of blocks, hence the term blockchain. As new transactions are added to the blockchain, they must be validated by nodes on the network, which ensures that all nodes agree on the state of the blockchain.
#
# On page 2, it is stated: "The proof-of-work algorithm, which we will describe below, makes it more difficult for an attacker to create a fake block." This suggests that the cryptographic hash functions used in Bitcoin's consensus mechanism make it computationally expensive and thus impractical for an attacker to attempt to manipulate the blockchain.
#
# In summary, Bitcoin prevents double spending without a central authority by using a decentralized network of nodes that verify transactions through a distributed ledger called the blockchain. The proof-of-work algorithm ensures that all nodes agree on the state of the blockchain, making it difficult for an attacker to create fake blocks or manipulate existing ones.
