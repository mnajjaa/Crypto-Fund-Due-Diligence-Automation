# %%
import requests
import pandas as pd
from IPython.display import display

# 1. Define API endpoint, parameters, and headers
url = "https://data-api.coindesk.com/news/v1/article/list"
params = {
    "lang": "EN",
    "limit": 20,
    "api_key": "bfba647c0655af318fc4c3cbb44a3532f7d0a89ca38f5129236ff07b40b004f9"
}
headers = {"Content-type": "application/json; charset=UTF-8"}

# 2. Make the API request
response = requests.get(url, params=params, headers=headers)

if response.status_code == 200:
    # 3. Parse JSON response
    json_response = response.json()
    
    # Extract the list of articles from the "Data" key
    articles = json_response.get("Data", [])
    
    if not articles:
        print("No articles found in the response.")
    else:
        # 4. Flatten nested structures using pd.json_normalize
        # This will flatten nested keys (e.g., SOURCE_DATA, CATEGORY_DATA)
        df = pd.json_normalize(articles, sep="_")
        
        print(f"Found {len(df)} articles.")
        display(df.head())
        
        # 5. Save the DataFrame to a CSV file
        csv_filename = "coindesk_articles.csv"
        df.to_csv(csv_filename, index=False)
        print(f"Data saved to {csv_filename}")
else:
    print(f"Request failed with status code {response.status_code}")
    print(response.text)
# Out:
# C:\Users\mahmo\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Found 20 articles.
#   TYPE        ID                                               GUID  \
# 0  121  40794385  https://en.coinotag.com/michael-saylor-propose...
# 1  121  40794323                       https://decrypt.co/?p=307566
# 2  121  40794521            https://en.bitcoinsistemi.com/?p=151315
# 3  121  40794118                     https://coingape.com/?p=240756
# 4  121  40794151                 https://en.coin-turk.com/?p=183671
#
#    PUBLISHED_ON                                          IMAGE_URL  \
# 0    1740444198  https://resources.cryptocompare.com/news/77/40...
# 1    1740444056  https://resources.cryptocompare.com/news/44/40...
# 2    1740444002  https://resources.cryptocompare.com/news/81/40...
# 3    1740443770  https://images.cryptocompare.com/news/default/...
# 4    1740443751  https://resources.cryptocompare.com/news/79/40...
#
#                                                TITLE  \
# 0  Michael Saylor Proposes Regulatory Reforms for...
# 1  Strategy CEO Michael Saylor Pitches Regulation...
# 2  Will MAGACOINOFFICIAL.COM Overtake XRP and SOL...
# 3  Shiba Inu Price Battles Support Levels With Bu...
# 4  Changpeng Zhao Shares His Crypto Portfolio: A ...
#
#                                                  URL  SOURCE_ID  \
# 0  https://en.coinotag.com/michael-saylor-propose...         77
# 1  https://decrypt.co/307566/strategy-ceo-michael...         44
# 2  https://en.bitcoinsistemi.com/will-magacoinoff...         81
# 3  https://coingape.com/shiba-inu-price-battles-s...         36
# 4  https://en.coin-turk.com/changpeng-zhao-shares...         79
#
#                                                 BODY  \
# 0  Regulatory discussions are heating up in the c...
# 1  At a meeting with regulators, Saylor proposed ...
# 2  A New Crypto Contender Is Emerging The crypto ...
# 3  Shiba Inu (SHIB) price is facing a challenging...
# 4  Changpeng Zhao has shared his crypto portfolio...
#
#                                             KEYWORDS  ...  \
# 0                                           News|BTC  ...
# 1                                      Law and Order  ...
# 2                                          Sponsored  ...
# 3  24/7 Cryptocurrency News|Altcoin News|Meme Coi...  ...
# 4                                            Binance  ...
#
#                        SOURCE_DATA_URL  SOURCE_DATA_LANG  \
# 0        https://en.coinotag.com/feed/                EN
# 1              https://decrypt.co/feed                EN
# 2  https://en.bitcoinsistemi.com/feed/                EN
# 3           https://coingape.com/feed/                EN
# 4       https://en.coin-turk.com/feed/                EN
#
#    SOURCE_DATA_SOURCE_TYPE  SOURCE_DATA_LAUNCH_DATE SOURCE_DATA_SORT_ORDER  \
# 0                      RSS                      NaN                      0
# 1                      RSS             1.521331e+09                      0
# 2                      RSS                      NaN                      0
# 3                      RSS             1.504224e+09                      0
# 4                      RSS                      NaN                      0
#
#   SOURCE_DATA_BENCHMARK_SCORE  SOURCE_DATA_STATUS  \
# 0                           0              ACTIVE
# 1                          57              ACTIVE
# 2                           0              ACTIVE
# 3                          60              ACTIVE
# 4                           0              ACTIVE
#
#    SOURCE_DATA_LAST_UPDATED_TS SOURCE_DATA_CREATED_ON SOURCE_DATA_UPDATED_ON
# 0                   1740444033             1686819961             1717748924
# 1                   1740444022             1657730129             1711620560
# 2                   1740444047             1692873798             1692873836
# 3                   1740444012             1657730129             1738248754
# 4                   1740444023             1689939795             1690273097
#
# [5 rows x 34 columns]
# Data saved to coindesk_articles.csv

# %%
df.describe()
# Out:
#                  ID  PUBLISHED_ON   SOURCE_ID  UPVOTES  DOWNVOTES  SCORE  \
# count  2.000000e+01  2.000000e+01   20.000000     20.0       20.0   20.0
# mean   4.079393e+07  1.740443e+09   61.100000      0.0        0.0    0.0
# std    4.880135e+02  9.758926e+02   23.427155      0.0        0.0    0.0
# min    4.079308e+07  1.740442e+09   14.000000      0.0        0.0    0.0
# 25%    4.079357e+07  1.740442e+09   43.750000      0.0        0.0    0.0
# 50%    4.079407e+07  1.740443e+09   62.000000      0.0        0.0    0.0
# 75%    4.079428e+07  1.740444e+09   77.000000      0.0        0.0    0.0
# max    4.079464e+07  1.740444e+09  101.000000      0.0        0.0    0.0
#
#          CREATED_ON    UPDATED_ON  SOURCE_DATA_ID  SOURCE_DATA_LAUNCH_DATE  \
# count  2.000000e+01  1.800000e+01       20.000000             9.000000e+00
# mean   1.740443e+09  1.740443e+09       61.100000             1.135526e+09
# std    9.310105e+02  9.828245e+02       23.427155             1.046763e+09
# min    1.740442e+09  1.740442e+09       14.000000            -1.650326e+09
# 25%    1.740443e+09  1.740442e+09       43.750000             1.404691e+09
# 50%    1.740444e+09  1.740444e+09       62.000000             1.504224e+09
# 75%    1.740444e+09  1.740444e+09       77.000000             1.521331e+09
# max    1.740445e+09  1.740445e+09      101.000000             1.592698e+09
#
#        SOURCE_DATA_SORT_ORDER  SOURCE_DATA_BENCHMARK_SCORE  \
# count                    20.0                    20.000000
# mean                      0.0                    18.500000
# std                       0.0                    26.027314
# min                       0.0                     0.000000
# 25%                       0.0                     0.000000
# 50%                       0.0                     0.000000
# 75%                       0.0                    49.250000
# max                       0.0                    60.000000
#
#        SOURCE_DATA_LAST_UPDATED_TS  SOURCE_DATA_CREATED_ON  \
# count                 2.000000e+01            2.000000e+01
# mean                  1.740444e+09            1.674037e+09
# std                   1.208860e+01            2.006789e+07
# min                   1.740444e+09            1.657730e+09
# 25%                   1.740444e+09            1.657730e+09
# 50%                   1.740444e+09            1.657730e+09
# 75%                   1.740444e+09            1.686820e+09
# max                   1.740444e+09            1.719065e+09
#
#        SOURCE_DATA_UPDATED_ON
# count            2.000000e+01
# mean             1.705880e+09
# std              1.761810e+07
# min              1.673256e+09
# 25%              1.692224e+09
# 50%              1.711621e+09
# 75%              1.717749e+09
# max              1.738249e+09

# %%
df.isnull().sum()
# Out:
# TYPE                            0
# ID                              0
# GUID                            0
# PUBLISHED_ON                    0
# IMAGE_URL                       0
# TITLE                           0
# URL                             0
# SOURCE_ID                       0
# BODY                            0
# KEYWORDS                        0
# LANG                            0
# UPVOTES                         0
# DOWNVOTES                       0
# SCORE                           0
# SENTIMENT                       0
# STATUS                          0
# CREATED_ON                      0
# UPDATED_ON                      2
# CATEGORY_DATA                   0
# SOURCE_DATA_TYPE                0
# SOURCE_DATA_ID                  0
# SOURCE_DATA_SOURCE_KEY          0
# SOURCE_DATA_NAME                0
# SOURCE_DATA_IMAGE_URL           0
# SOURCE_DATA_URL                 0
# SOURCE_DATA_LANG                0
# SOURCE_DATA_SOURCE_TYPE         0
# SOURCE_DATA_LAUNCH_DATE        11
# SOURCE_DATA_SORT_ORDER          0
# SOURCE_DATA_BENCHMARK_SCORE     0
# SOURCE_DATA_STATUS              0
# SOURCE_DATA_LAST_UPDATED_TS     0
# SOURCE_DATA_CREATED_ON          0
# SOURCE_DATA_UPDATED_ON          0
# dtype: int64
